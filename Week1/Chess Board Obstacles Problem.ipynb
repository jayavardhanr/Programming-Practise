# %%
#!/bin/python

import sys
n,k = raw_input().strip().split(' ')
n,k = [int(n),int(k)]
rQueen,cQueen = raw_input().strip().split(' ')
rQueen,cQueen = [int(rQueen),int(cQueen)]

d_min=min(n-rQueen,cQueen-1)
diagnol1=(rQueen+d_min,cQueen-d_min)

d_min=min(n-rQueen,n-cQueen)
diagnol2=(rQueen+d_min,cQueen+d_min)

d_min=min(rQueen-1,n-cQueen)
diagnol3=(rQueen-d_min,cQueen+d_min)

d_min=min(rQueen-1,cQueen-1)
diagnol4=(rQueen-d_min,cQueen-d_min)

neg_axis1=(rQueen,1)
pos_axis1=(rQueen,n)
neg_axis2=(1,cQueen)
pos_axis2=(n,cQueen)

print(diagnol1,diagnol2,diagnol3,diagnol4,neg_axis1,pos_axis1,neg_axis2,pos_axis2)

for a0 in xrange(k):
    
    rObstacle,cObstacle = raw_input().strip().split(' ')
    rObstacle,cObstacle = (int(rObstacle),int(cObstacle))
    # your code goes here
    if rQueen==rObstacle:
        if cQueen>cObstacle:
            neg_axis1=(rObstacle,cObstacle+1)
        else:
            pos_axis1=(rObstacle,cObstacle-1)
    elif cQueen==cObstacle:
        if rQueen>rObstacle:
            neg_axis2=(rObstacle+1,cObstacle)
        else:
            pos_axis2=(rObstacle-1,cObstacle)
    else:
        if (rObstacle-rQueen)==-1*(cQueen-cObstacle):
            if (rObstacle-rQueen)>0:
                diagnol2=(rObstacle-1,cObstacle-1)
            else:
                diagnol4=(rObstacle+1,cObstacle+1)
                

        elif (rObstacle-rQueen)==1*(cQueen-cObstacle):
            if (rObstacle-rQueen)>0:
                diagnol1=(rObstacle-1,cObstacle+1)
            else:
                diagnol3=(rObstacle+1,cObstacle-1)
        
        else:
            pass
    print(diagnol1,diagnol2,diagnol3,diagnol4,neg_axis1,pos_axis1,neg_axis2,pos_axis2)

count=0

for point in [diagnol1,diagnol2,diagnol3,diagnol4,neg_axis1,pos_axis1,neg_axis2,pos_axis2]:
    count+=max(abs(rQueen-point[0]),abs(cQueen-point[1]))
    
print(count)
# Out:
# 5 8
# 3 3
# ((5, 1), (5, 5), (1, 5), (1, 1), (3, 1), (3, 5), (1, 3), (5, 3))
# 5 1
# ((4, 2), (5, 5), (1, 5), (1, 1), (3, 1), (3, 5), (1, 3), (5, 3))
# 5 5
# ((4, 2), (4, 4), (1, 5), (1, 1), (3, 1), (3, 5), (1, 3), (5, 3))
# 1 5
# ((4, 2), (4, 4), (2, 4), (1, 1), (3, 1), (3, 5), (1, 3), (5, 3))
# 1 1
# ((4, 2), (4, 4), (2, 4), (2, 2), (3, 1), (3, 5), (1, 3), (5, 3))
# 3 1
# ((4, 2), (4, 4), (2, 4), (2, 2), (3, 2), (3, 5), (1, 3), (5, 3))
# 3 5
# ((4, 2), (4, 4), (2, 4), (2, 2), (3, 2), (3, 4), (1, 3), (5, 3))
# 1 3
# ((4, 2), (4, 4), (2, 4), (2, 2), (3, 2), (3, 4), (2, 3), (5, 3))
# 5 3
# ((4, 2), (4, 4), (2, 4), (2, 2), (3, 2), (3, 4), (2, 3), (4, 3))
# 8

# %%
#!/bin/python

import sys
n,k = raw_input().strip().split(' ')
n,k = [int(n),int(k)]
rQueen,cQueen = raw_input().strip().split(' ')
rQueen,cQueen = [int(rQueen),int(cQueen)]

barrier_up_left=min(n-rQueen,abs(cQueen-1))
barrier_up_right=min(n-rQueen,n-cQueen)
barrier_down_right=min(rQueen-1,n-cQueen)
barrier_down_left=min(rQueen-1,cQueen-1)
barrier_left=cQueen-1
barrier_right=n-cQueen
barrier_below=rQueen-1
barrier_above=n-rQueen

for a0 in xrange(k):
    
    rObstacle,cObstacle = raw_input().strip().split(' ')
    rObstacle,cObstacle = (int(rObstacle),int(cObstacle))
    # your code goes here
    if rQueen==rObstacle:
        if cQueen>cObstacle:
        else:
    elif cQueen==cObstacle:
        if rQueen>rObstacle:
        else:
    else:
        if (rObstacle-rQueen)==-1*(cQueen-cObstacle):
            if (rObstacle-rQueen)>0:
            else:

        elif (rObstacle-rQueen)==1*(cQueen-cObstacle):
            if (rObstacle-rQueen)>0:
            else:
        
        else:
            pass
    print(diagnol1,diagnol2,diagnol3,diagnol4,neg_axis1,pos_axis1,neg_axis2,pos_axis2)

count=0

for point in [diagnol1,diagnol2,diagnol3,diagnol4,neg_axis1,pos_axis1,neg_axis2,pos_axis2]:
    count+=max(abs(rQueen-point[0]),abs(cQueen-point[1]))
    
print(count)
