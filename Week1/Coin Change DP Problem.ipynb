# %%
#!/bin/python

import sys

def getWays(n, c):
    # Complete this function
    d=[0]*(n+1)
    for i in range(1,n+1):
        i=long(i)
        for coin in c:
            print(i,coin)
            if coin==i or ((i-coin)==coin) :
                print('equal',i,coin)
                d[i]+=1
            elif (coin<i) and ((i-coin)>coin):
                print('not equal',i,i-coin,coin)
                d[i]+=d[i-coin]
    
    print(d)
    ways=d[n]
    return ways
        

n, m = raw_input().strip().split(' ')
n, m = [int(n), int(m)]
c = map(long, raw_input().strip().split(' '))
# Print the number of ways of making change for 'n' units using coins having the values given by 'c'
ways = getWays(n, c)

print(ways)
# Out:
# 10 4
# 2 5 3 6
# (1L, 2L)
# (1L, 5L)
# (1L, 3L)
# (1L, 6L)
# (2L, 2L)
# ('equal', 2L, 2L)
# (2L, 5L)
# (2L, 3L)
# (2L, 6L)
# (3L, 2L)
# (3L, 5L)
# (3L, 3L)
# ('equal', 3L, 3L)
# (3L, 6L)
# (4L, 2L)
# ('equal', 4L, 2L)
# (4L, 5L)
# (4L, 3L)
# (4L, 6L)
# (5L, 2L)
# ('not equal', 5L, 3L, 2L)
# (5L, 5L)
# ('equal', 5L, 5L)
# (5L, 3L)
# (5L, 6L)
# (6L, 2L)
# ('not equal', 6L, 4L, 2L)
# (6L, 5L)
# (6L, 3L)
# ('equal', 6L, 3L)
# (6L, 6L)
# ('equal', 6L, 6L)
# (7L, 2L)
# ('not equal', 7L, 5L, 2L)
# (7L, 5L)
# (7L, 3L)
# ('not equal', 7L, 4L, 3L)
# (7L, 6L)
# (8L, 2L)
# ('not equal', 8L, 6L, 2L)
# (8L, 5L)
# (8L, 3L)
# ('not equal', 8L, 5L, 3L)
# (8L, 6L)
# (9L, 2L)
# ('not equal', 9L, 7L, 2L)
# (9L, 5L)
# (9L, 3L)
# ('not equal', 9L, 6L, 3L)
# (9L, 6L)
# (10L, 2L)
# ('not equal', 10L, 8L, 2L)
# (10L, 5L)
# ('equal', 10L, 5L)
# (10L, 3L)
# ('not equal', 10L, 7L, 3L)
# (10L, 6L)
# [0, 0, 1, 1, 1, 2, 3, 3, 5, 6, 9]
# 9
